# %%
# Creating an empty list for SE COMP
SEComp = []
n = int(input("Enter number of students in SE COMP: "))
print("Enter the names of",n,"students (Please press ENTER after entering each students name) :")
for i in range(0, n):
    names = input()
    SEComp.append(names)  # adding the element
print("Original list of students : ",SEComp)


# Creating an empty list for Cricket
Cricket = []
n = int(input("\n\nEnter number of students who play cricket : "))
print("Enter the names of",n,"students who play cricket (Please press ENTER after entering each students name) :")
for i in range(0, n):
    GROUPA = input()
    Cricket.append(GROUPA)
print("Original list of students playing cricket is :",Cricket)


# Creating an empty list for Football
Football = []
n = int(input("\n\nEnter number of students who play football : "))
print("Enter the name of",n,"students who play football (Please press ENTER after entering each students name) :")
for i in range(0, n):
    GROUPC = input()
    Football.append(GROUPC) 
print("Original list of students playing football :" ,Football)


# Creating an empty list for Badminton
Badminton = []
n = int(input("\n\nEnter number of students who play badminton : "))
print("Enter the name of",n,"students who play badminton (Please press ENTER after entering each students name) :")
for i in range(0, n):
    GROUPB = input()
    Badminton.append(GROUPB)
print("Original list of students playing badminton :",Badminton)

def intersection(lst1,lst2):          # logic for intersection
    lst3=[]
    for val in lst1:                # in while loop when intersection is requested cricket and badminton
        if val in lst2:          # lists are checked accordingly named list 1 and list2 , if list1 values are in list2
            lst3.append(val)     # new list is created list3
    return lst3                  
       

def union(lst1,lst2):          
    lst3=lst1.copy()
    for val in lst2:
        if val not in lst3:
            lst3.append(val)
    return lst3


def diff(lst1,lst2):
    lst3=[]
    for val in lst1:
        if val not in lst2:
            lst3.append(val)
    return lst3

#<---------------------------------------------------------------------------------------------->

# Function for finding symmetric difference of two sets (A^B)

def sym_diff(lst1,lst2):
    lst3=[]
    D1=diff(lst1,lst2)
    print("Difference between Cricket and Badminton (C-B) is : ", D1)
    D2=diff(lst2,lst1)
    print("Difference between Badminton and Cricket (B-C) is : ", D2)
    lst3=union(D1,D2)
    return lst3

#<------------------------------------------------------------------------------------------------>

# Functon for finding List of students who play both cricket and badminton

def CB(lst1,lst2):
    lst3=intersection(lst1,lst2)
    print("\n\nList of students who play both cricket and badminton is : ", lst3)
    return len(lst3)

#<------------------------------------------------------------------------------------------------>

# Function for finding List of students who play either cricket or badminton but not both

def eCeB(lst1,lst2):
    lst3=sym_diff(lst1,lst2)
    print("\nList of students who play either cricket or badminton but not both is : ",lst3)
    return len(lst3)

#<-------------------------------------------------------------------------------------------------->

# Function for finding Number of students who play neither cricket nor badminton

def nCnB(lst1,lst2,lst3):
    lst4=diff(lst1,union(lst2,lst3))
    print("\n\nList of students who play neither cricket nor badminton is : ",lst4)
    return len(lst4)

#<--------------------------------------------------------------------------------------------------->

# Function for finding Number of students who play cricket and football but not badminton

def CBnF(lst1,lst2,lst3):
    lst4=diff(intersection(lst1,lst2),lst3)
    print("\n\nList of students who play cricket and football but not badminton is : ",lst4)
    return len(lst4)

#<----------------------------------------------------------------------------------------------------->


flag=1
while flag==1:
    print("\n\n--------------------MENU--------------------\n")
    print("1. List of students who play both cricket and badminton")
    print("2. List of students who play either cricket or badminton but not both")
    print("3. List of students who play neither cricket nor badminton")
    print("4. Number of students who play cricket and football but not badminton")  #union of c and f
    print("5. Exit\n")
    ch=int(input("Enter your Choice (from 1 to 5) :"))

    if ch==1:
        print("Number of students who play both cricket and badminton : ", intersection(Cricket,Badminton)) 
        a = input("\n\nDo you want to continue (yes/no) :")                  #
        if a == "yes":                                                      # 
            flag = 1
        else:
            flag = 0
            print("Thanks for using this program!")
    elif ch==2:
        print("Number of students who play either cricket or badminton but not both : ", eCeB(Cricket, Badminton))
        a = input("\n\nDo you want to continue (yes/no) :")
        if a == "yes":
            flag = 1
        else:
            flag = 0
            print("Thanks for using this program!")

    elif ch==3:
        print("Number of students who play neither cricket nor badminton : ", nCnB(SEComp,Cricket,Badminton))
        a = input("\n\nDo you want to continue (yes/no) :")
        if a == "yes":
            flag = 1
        else:
            flag = 0
            print("Thanks for using this program!")

    elif ch==4:
        print("Number of students who play cricket and football but not badminton : ", CBnF(Cricket,Football,Badminton))
        a = input("\n\nDo you want to continue (yes/no) :")
        if a == "yes":
            flag = 1
        else:
            flag = 0
            print("Thanks for using this program!")

    elif ch==5:
        flag=0
        print("Thanks for using this program!")

    else:
        print("!!Wrong Choice!! ")
        a=input("\n\nDo you want to continue (yes/no) :")
        if a=="yes":
            flag=1
        else:
            flag=0
            print("Thanks for using this program!")

#<---------------------------------------------END OF PROGRAM--------------------------------------->
# Out:
# Enter number of students in SE COMP: 6
# Enter the names of 6 students (Please press ENTER after entering each students name) :
# 1
# 2
# 3
# 4
# 5
# 6
# Original list of students :  ['1', '2', '3', '4', '5', '6']
#
#
# Enter number of students who play cricket : 5
# Enter the names of 5 students who play cricket (Please press ENTER after entering each students name) :
# 1
# 2
# 3
# 4
# 5
# Original list of students playing cricket is : ['1', '2', '3', '4', '5']
#
#
# Enter number of students who play football : 3
# Enter the name of 3 students who play football (Please press ENTER after entering each students name) :
# 4
# 5
# 6
# Original list of students playing football : ['4', '5', '6']
#
#
# Enter number of students who play badminton : 4
# Enter the name of 4 students who play badminton (Please press ENTER after entering each students name) :
# 1
# 2
# 5
# 6
# Original list of students playing badminton : ['1', '2', '5', '6']
#
#
# --------------------MENU--------------------
#
# 1. List of students who play both cricket and badminton
# 2. List of students who play either cricket or badminton but not both
# 3. List of students who play neither cricket nor badminton
# 4. Number of students who play cricket and football but not badminton
# 5. Exit
#
# Enter your Choice (from 1 to 5) :1
# Number of students who play both cricket and badminton :  ['1', '2', '5']
#
#
# Do you want to continue (yes/no) :yes
#
#
# --------------------MENU--------------------
#
# 1. List of students who play both cricket and badminton
# 2. List of students who play either cricket or badminton but not both
# 3. List of students who play neither cricket nor badminton
# 4. Number of students who play cricket and football but not badminton
# 5. Exit
#
# Enter your Choice (from 1 to 5) :2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-cf16950f94a2> in <module>
#      81             print("Thanks for using this program!")
#      82     elif ch==2:
# ---> 83         print("Number of students who play either cricket or badminton but not both : ", eCeB(Cricket, Badminton))
#      84         a = input("\n\nDo you want to continue (yes/no) :")
#      85         if a == "yes":
#
# NameError: name 'eCeB' is not defined
